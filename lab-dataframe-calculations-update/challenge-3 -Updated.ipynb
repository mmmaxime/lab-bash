# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

orders = pd.read_csv('Orders.csv')
orders.value_counts()
# Out:
# Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  Description                         Quantity  InvoiceDate          UnitPrice  CustomerID  Country         amount_spent
# 0           536365     85123A     2010  12     3    8     white hanging heart t-light holder  6         2010-12-01 08:26:00  2.55       17850       United Kingdom  15.30           1
# 369246      569021     85150      2011  9      5    9     ladies & gentlemen metal sign       6         2011-09-30 09:40:00  2.55       15321       United Kingdom  15.30           1
# 369268      569024     23368      2011  9      5    10    set 12 colour pencils dolly girl    16        2011-09-30 10:04:00  0.65       12822       United Kingdom  10.40           1
# 369267      569024     23367      2011  9      5    10    set 12 colour pencils spaceboy      16        2011-09-30 10:04:00  0.65       12822       United Kingdom  10.40           1
# 369266      569022     23026      2011  9      5    9     drawer knob vintage glass star      6         2011-09-30 09:45:00  2.08       17725       United Kingdom  12.48           1
#                                                                                                                                                                                    ..
# 192609      553461     21084      2011  5      2    10    set/6 collage paper cups            24        2011-05-17 10:57:00  0.19       16316       United Kingdom  4.56            1
# 192608      553461     21090      2011  5      2    10    set/6 collage paper plates          24        2011-05-17 10:57:00  0.39       16316       United Kingdom  9.36            1
# 192607      553461     21089      2011  5      2    10    set/6 green spring paper cups       12        2011-05-17 10:57:00  0.19       16316       United Kingdom  2.28            1
# 192606      553461     22962      2011  5      2    10    jam jar with pink lid               12        2011-05-17 10:57:00  0.85       16316       United Kingdom  10.20           1
# 541908      581587     22138      2011  12     5    12    baking set 9 piece retrospot        3         2011-12-09 12:50:00  4.95       12680       France          14.85           1
# Length: 397924, dtype: int64

# %% [markdown]
# Next, extract and import `Orders` dataset into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34

# %%
orders = orders.drop(columns=['Unnamed: 0'], axis=1)
orders.head()
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
# 3     536365    84029G  2010     12    3     8
# 4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
orders[['CustomerID','amount_spent']]
orders['CustomerID'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 397919    12680
# 397920    12680
# 397921    12680
# 397922    12680
# 397923    12680
# Name: CustomerID, Length: 397924, dtype: int64>

# %%
# Sum amount of every customer groupby customer_id
upper_limit = np.quantile(orders.groupby(['CustomerID']).agg({'amount_spent':sum}),0.95)
print(upper_limit)
sum_customers = orders.groupby(['CustomerID']).agg({'amount_spent':sum})

VIP_customers = sum_customers[(sum_customers['amount_spent']>= upper_limit)]
VIP_customers.shape
# Out:
# 5840.181999999982
# (217, 1)

# %%
print(upper_limit)
lower_limit = np.quantile(orders.groupby(['CustomerID']).agg({'amount_spent':sum}),0.75)
print(lower_limit)
# Out:
# 5840.181999999982
# 1661.64

# %%
P_customers = sum_customers[(sum_customers['amount_spent'].between(lower_limit, upper_limit))]
P_customers.shape
# Out:
# (868, 1)

# %%
others = sum_customers[(sum_customers['amount_spent']< lower_limit)]
others
# Out:
#             amount_spent
# CustomerID
# 12350             334.40
# 12353              89.00
# 12354            1079.40
# 12355             459.40
# 12358            1168.06
# ...                  ...
# 18277             110.38
# 18278             173.90
# 18280             180.60
# 18281              80.82
# 18282             178.05
#
# [3254 rows x 1 columns]

# %%
sum_customers = sum_customers.reset_index()

# %%
customer_labels = []
for x in sum_customers['amount_spent']:
    if x >= upper_limit:
        x = 'VIP'
        customer_labels.append(x)
    elif x <= lower_limit:
        x = 'Preferred'
        customer_labels.append(x)
    else:
        x = 'others'
        customer_labels.append(x)
customer_id = []
for i in sum_customers['CustomerID']:
    customer_id.append(i)
    
customer_labels
customer_id
# Out:
# [12346,
#  12347,
#  12348,
#  12349,
#  12350,
#  12352,
#  12353,
#  12354,
#  12355,
#  12356,
#  12357,
#  12358,
#  12359,
#  12360,
#  12361,
#  12362,
#  12363,
#  12364,
#  12365,
#  12367,
#  13068,
#  13069,
#  13070,
#  13072,
#  13075,
#  13077,
#  13078,
#  13079,
#  13080,
#  13081,
#  13082,
#  13083,
#  13085,
#  13089,
#  13090,
#  13091,
#  13092,
#  13093,
#  13094,
#  13095,
#  13097,
#  13098,
#  13099,
#  13101,
#  13102,
#  13103,
#  13104,
#  13106,
#  13107,
#  13108,
#  13109,
#  13110,
#  13113,
#  13115,
#  13116,
#  13117,
#  13118,
#  13120,
#  13121,
#  13122,
#  13124,
#  13126,
#  13127,
#  13130,
#  13131,
#  13132,
#  13133,
#  13134,
#  13135,
#  13136,
#  13137,
#  13138,
#  13139,
#  13140,
#  13141,
#  13142,
#  13144,
#  13145,
#  13146,
#  13147,
#  13148,
#  13149,
#  13151,
#  13153,
#  13155,
#  13157,
#  13158,
#  13159,
#  13160,
#  13161,
#  13162,
#  13165,
#  13166,
#  13167,
#  13168,
#  13169,
#  13170,
#  13171,
#  13173,
#  13174,
#  13176,
#  13177,
#  13178,
#  13182,
#  13183,
#  13184,
#  13185,
#  13186,
#  13187,
#  13188,
#  13189,
#  13192,
#  13193,
#  13194,
#  13196,
#  13198,
#  13199,
#  13200,
#  13203,
#  13207,
#  13208,
#  13209,
#  13210,
#  13211,
#  13212,
#  13213,
#  13216,
#  13217,
#  13218,
#  13220,
#  13221,
#  13223,
#  13224,
#  13225,
#  13226,
#  13227,
#  13228,
#  13229,
#  13230,
#  13232,
#  13233,
#  13235,
#  13236,
#  13238,
#  13239,
#  13240,
#  13242,
#  13243,
#  13244,
#  13245,
#  13246,
#  13247,
#  13248,
#  13249,
#  13253,
#  13255,
#  13256,
#  13258,
#  13259,
#  13260,
#  13261,
#  13262,
#  13263,
#  13265,
#  13266,
#  13267,
#  13268,
#  13269,
#  13270,
#  13271,
#  13272,
#  13273,
#  13276,
#  13277,
#  13278,
#  13279,
#  13280,
#  13282,
#  13283,
#  13284,
#  13285,
#  13291,
#  13292,
#  13294,
#  13295,
#  13296,
#  13297,
#  13298,
#  13299,
#  13300,
#  13301,
#  13302,
#  13304,
#  13305,
#  13307,
#  13308,
#  13309,
#  13310,
#  13311,
#  13313,
#  13314,
#  13316,
#  13317,
#  13318,
#  13319,
#  13320,
#  13321,
#  13322,
#  13323,
#  13324,
#  13325,
#  13327,
#  13328,
#  13329,
#  13330,
#  13332,
#  13334,
#  13336,
#  13338,
#  13339,
#  13340,
#  13341,
#  13343,
#  13344,
#  13345,
#  13347,
#  13348,
#  13349,
#  13350,
#  13351,
#  13352,
#  13354,
#  13355,
#  13356,
#  13357,
#  13358,
#  13359,
#  13362,
#  13363,
#  13364,
#  13365,
#  13366,
#  13368,
#  13369,
#  13370,
#  13372,
#  13373,
#  13375,
#  13376,
#  13379,
#  13381,
#  13382,
#  13384,
#  13385,
#  13388,
#  13389,
#  13390,
#  13391,
#  13394,
#  13395,
#  13396,
#  13397,
#  13398,
#  13402,
#  13403,
#  13404,
#  13405,
#  13408,
#  13410,
#  13411,
#  13414,
#  13416,
#  13417,
#  13418,
#  13419,
#  13420,
#  13421,
#  13422,
#  13425,
#  13426,
#  13427,
#  13428,
#  13429,
#  13430,
#  13431,
#  13434,
#  13435,
#  13436,
#  13437,
#  13439,
#  13441,
#  13447,
#  13448,
#  13449,
#  13450,
#  13451,
#  13452,
#  13453,
#  13455,
#  13456,
#  13458,
#  13460,
#  13461,
#  13462,
#  13464,
#  13466,
#  13467,
#  13468,
#  13470,
#  13471,
#  13473,
#  13474,
#  13475,
#  13476,
#  13477,
#  13479,
#  13481,
#  13482,
#  13483,
#  13484,
#  13485,
#  13486,
#  13487,
#  13488,
#  13489,
#  13491,
#  13492,
#  13493,
#  13494,
#  13495,
#  13496,
#  13497,
#  13499,
#  13500,
#  13501,
#  13502,
#  13503,
#  13504,
#  13505,
#  13506,
#  13507,
#  13508,
#  13509,
#  13510,
#  13512,
#  13513,
#  13514,
#  13515,
#  13516,
#  13517,
#  13518,
#  13519,
#  13520,
#  13521,
#  13522,
#  13523,
#  13524,
#  13525,
#  13527,
#  13529,
#  13531,
#  13532,
#  13533,
#  13534,
#  13536,
#  13538,
#  13539,
#  13544,
#  13546,
#  13548,
#  13549,
#  13551,
#  13552,
#  13555,
#  13557,
#  13558,
#  13560,
#  13561,
#  13562,
#  13563,
#  13564,
#  13565,
#  13566,
#  13568,
#  13569,
#  13570,
#  13571,
#  13572,
#  13573,
#  13575,
#  13576,
#  13577,
#  13579,
#  13581,
#  13583,
#  13584,
#  13587,
#  13588,
#  13589,
#  13590,
#  13591,
#  13592,
#  13593,
#  13594,
#  13596,
#  13598,
#  13599,
#  13600,
#  13601,
#  13602,
#  13603,
#  13606,
#  13607,
#  13610,
#  13611,
#  13614,
#  13615,
#  13617,
#  13618,
#  13621,
#  13623,
#  13626,
#  13627,
#  13629,
#  13630,
#  13631,
#  13632,
#  13634,
#  13635,
#  13636,
#  13637,
#  13638,
#  13639,
#  13642,
#  13643,
#  13644,
#  13645,
#  13647,
#  13649,
#  13650,
#  13651,
#  13652,
#  13654,
#  13655,
#  13656,
#  13657,
#  13658,
#  13659,
#  13662,
#  13663,
#  13666,
#  13667,
#  13668,
#  13669,
#  13670,
#  13672,
#  13673,
#  13675,
#  13678,
#  13680,
#  13681,
#  13682,
#  13684,
#  13685,
#  13686,
#  13689,
#  13690,
#  13692,
#  13694,
#  13695,
#  13697,
#  ...]

# %%
customer_id = pd.DataFrame(customer_id, columns = ['CustomerID'])
customers_labels = pd.DataFrame(customer_labels, columns = ['customers_label'])

# %%
customers_labels
# Out:
#      customers_label
# 0                VIP
# 1             others
# 2             others
# 3             others
# 4          Preferred
# ...              ...
# 4334       Preferred
# 4335       Preferred
# 4336       Preferred
# 4337          others
# 4338          others
#
# [4339 rows x 1 columns]

# %%
customer_id
# Out:
#       CustomerID
# 0          12346
# 1          12347
# 2          12348
# 3          12349
# 4          12350
# ...          ...
# 4334       18280
# 4335       18281
# 4336       18282
# 4337       18283
# 4338       18287
#
# [4339 rows x 1 columns]

# %%
customer_group = pd.concat([customers_labels,customer_id],axis=1)
customer_group
# Out:
#      customers_label  CustomerID
# 0                VIP       12346
# 1             others       12347
# 2             others       12348
# 3             others       12349
# 4          Preferred       12350
# ...              ...         ...
# 4334       Preferred       18280
# 4335       Preferred       18281
# 4336       Preferred       18282
# 4337          others       18283
# 4338          others       18287
#
# [4339 rows x 2 columns]

# %%
orders = pd.DataFrame.merge(orders,customer_group,on='CustomerID')
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581578     22993  2011     12    5    12
# 397920     581578     22907  2011     12    5    12
# 397921     581578     22908  2011     12    5    12
# 397922     581578     23215  2011     12    5    12
# 397923     581578     22736  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4            red woolly hottie white heart.         6  2010-12-01 08:26:00
# ...                                     ...       ...                  ...
# 397919         set of 4 pantry jelly moulds        12  2011-12-09 12:16:00
# 397920     pack of 20 napkins pantry design        12  2011-12-09 12:16:00
# 397921        pack of 20 napkins red apples        12  2011-12-09 12:16:00
# 397922     jingle bell heart antique silver        12  2011-12-09 12:16:00
# 397923          ribbon reel making snowmen         10  2011-12-09 12:16:00
#
#         UnitPrice  CustomerID         Country  amount_spent customers_label
# 0            2.55       17850  United Kingdom         15.30          others
# 1            3.39       17850  United Kingdom         20.34          others
# 2            2.75       17850  United Kingdom         22.00          others
# 3            3.39       17850  United Kingdom         20.34          others
# 4            3.39       17850  United Kingdom         20.34          others
# ...           ...         ...             ...           ...             ...
# 397919       1.25       12713         Germany         15.00       Preferred
# 397920       0.85       12713         Germany         10.20       Preferred
# 397921       0.85       12713         Germany         10.20       Preferred
# 397922       2.08       12713         Germany         24.96       Preferred
# 397923       1.65       12713         Germany         16.50       Preferred
#
# [397924 rows x 14 columns]

# %%
orders['customers_label'].value_counts()
# Out:
# others       151781
# Preferred    141659
# VIP          104484
# Name: customers_label, dtype: int64

# %%
orders.groupby(['customers_label']).agg({'amount_spent':np.mean, 'CustomerID': pd.Series.nunique}).reset_index()
# Out:
#   customers_label  amount_spent  CustomerID
# 0       Preferred     13.129150        3254
# 1             VIP     42.967346         217
# 2          others     16.880541         868

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
orders[orders.customers_label == 'VIP'].pivot_table(index=['Country','customers_label'],values = ['CustomerID'],aggfunc = lambda x: len(x.unique())).reset_index().sort_values(by=['CustomerID'],ascending = False).head(1)
# Out:
#            Country customers_label  CustomerID
# 17  United Kingdom             VIP         177

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
VIP_Pref = pd.concat([VIP_cust_country,Preferred_cust_country]).groupby(level=0).sum()
VIP_Pref.sort_values(by= 'amount_spent',ascending= False).head(5)

# %%
orders.query('customers_label == ["VIP","Preferred"]').pivot_table(index=['Country','customers_label'],values = ['CustomerID'],aggfunc = lambda x: len(x.unique())).reset_index().sort_values(by=['CustomerID'],ascending = False).head(1)
# Out:
#            Country customers_label  CustomerID
# 48  United Kingdom       Preferred        2989
